# %%
from sklearn.datasets import make_classification

# %%
X, y = make_classification(n_samples = 2000, n_classes = 2, n_features = 10, random_state = 48)

# %%
print(type(X))
print(type(y))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
print(X)
print(y)
# Out:
# [[-0.65791402  0.91622226  0.8271397  ...  1.88214685 -2.78221383
#    0.46740546]
#  [-0.44659091 -0.34425477 -0.37617447 ... -0.15347093 -0.6355701
#    1.32044194]
#  [-1.03958725 -0.59218806 -1.47793983 ... -0.02967223 -1.10895719
#    0.01532822]
#  ...
#  [ 0.5091983  -0.23716855 -0.477344   ... -0.21041033  1.44057187
#    0.32902573]
#  [ 1.29950003  0.61182718  1.75228846 ... -1.26403333 -0.0117824
#    1.55248678]
#  [-0.22255991 -1.59281499 -0.00683612 ...  1.75599049 -0.97419486
#    1.35326538]]
# [1 0 1 ... 1 0 1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.75, random_state=8)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(max_features=5, n_estimators=500)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_features=5, n_estimators=500)

# %%
lr_model = LogisticRegression()
lr_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
rf_probs = rf_model.predict_proba(X_test)
print(rf_probs)
# Out:
# [[0.002 0.998]
#  [0.67  0.33 ]
#  [0.734 0.266]
#  [0.814 0.186]
#  [0.922 0.078]
#  [0.956 0.044]
#  [0.654 0.346]
#  [0.872 0.128]
#  [0.964 0.036]
#  [1.    0.   ]
#  [0.112 0.888]
#  [0.002 0.998]
#  [0.954 0.046]
#  [0.998 0.002]
#  [0.942 0.058]
#  [0.    1.   ]
#  [0.108 0.892]
#  [0.026 0.974]
#  [0.002 0.998]
#  [1.    0.   ]
#  [0.952 0.048]
#  [0.956 0.044]
#  [0.652 0.348]
#  [0.996 0.004]
#  [0.01  0.99 ]
#  [0.912 0.088]
#  [0.004 0.996]
#  [0.    1.   ]
#  [0.    1.   ]
#  [0.008 0.992]
#  [0.    1.   ]
#  [0.02  0.98 ]
#  [0.    1.   ]
#  [0.926 0.074]
#  [0.756 0.244]
#  [0.97  0.03 ]
#  [0.    1.   ]
#  [0.    1.   ]
#  [0.    1.   ]
#  [0.932 0.068]
#  [0.008 0.992]
#  [0.924 0.076]
#  [0.738 0.262]
#  [0.816 0.184]
#  [0.73  0.27 ]
#  [0.984 0.016]
#  [0.59  0.41 ]
#  [0.816 0.184]
#  [0.822 0.178]
#  [0.988 0.012]
#  [0.882 0.118]
#  [0.068 0.932]
#  [0.976 0.024]
#  [0.02  0.98 ]
#  [0.05  0.95 ]
#  [0.976 0.024]
#  [0.976 0.024]
#  [0.93  0.07 ]
# ...

# %%
lr_probs=lr_model.predict_proba(X_test)
print(lr_probs)
# Out:
# [[6.18849378e-02 9.38115062e-01]
#  [8.51685892e-01 1.48314108e-01]
#  [7.14884829e-01 2.85115171e-01]
#  [3.53129980e-01 6.46870020e-01]
#  [8.75824401e-01 1.24175599e-01]
#  [8.47582472e-01 1.52417528e-01]
#  [5.68997579e-01 4.31002421e-01]
#  [7.20345004e-01 2.79654996e-01]
#  [3.02692647e-01 6.97307353e-01]
#  [9.81421958e-01 1.85780419e-02]
#  [1.06428290e-01 8.93571710e-01]
#  [4.80592487e-03 9.95194075e-01]
#  [9.07317396e-01 9.26826041e-02]
#  [7.27366374e-01 2.72633626e-01]
#  [9.38521819e-01 6.14781810e-02]
#  [5.00920863e-04 9.99499079e-01]
#  [3.60194770e-01 6.39805230e-01]
#  [8.11243127e-04 9.99188757e-01]
#  [1.57418407e-02 9.84258159e-01]
#  [9.38686641e-01 6.13133590e-02]
#  [9.71627863e-01 2.83721366e-02]
#  [9.45456134e-01 5.45438662e-02]
#  [7.69763749e-01 2.30236251e-01]
#  [8.94307708e-01 1.05692292e-01]
#  [1.58633463e-02 9.84136654e-01]
#  [7.50796072e-01 2.49203928e-01]
#  [5.69991525e-04 9.99430008e-01]
#  [1.32608525e-02 9.86739147e-01]
# ...

# %%
lr_probs = lr_probs[:, 1]
rf_probs = rf_probs[:, 1]

# %%
print(lr_probs)
print(rf_probs)
# Out:
# [0.93811506 0.14831411 0.28511517 0.64687002 0.1241756  0.15241753
#  0.43100242 0.279655   0.69730735 0.01857804 0.89357171 0.99519408
#  0.0926826  0.27263363 0.06147818 0.99949908 0.63980523 0.99918876
#  0.98425816 0.06131336 0.02837214 0.05454387 0.23023625 0.10569229
#  0.98413665 0.24920393 0.99943001 0.98673915 0.89913416 0.99349554
#  0.99925856 0.70147788 0.982482   0.08781899 0.31086053 0.02028372
#  0.99958278 0.97683432 0.85753789 0.10063492 0.98157125 0.10508396
#  0.02889675 0.40188747 0.4624843  0.62424587 0.29974515 0.47582397
#  0.18617116 0.21496528 0.43716237 0.52267028 0.23758415 0.9401023
#  0.39934694 0.10651723 0.08233202 0.08081627 0.17134187 0.17248791
#  0.00976    0.39794908 0.98786983 0.0257571  0.98127013 0.14546712
#  0.78163022 0.20191667 0.62260806 0.05058524 0.33407214 0.99479777
#  0.97246915 0.9973039  0.38289286 0.38030408 0.99586444 0.96224404
#  0.37076531 0.93947268 0.12940986 0.02970558 0.9495351  0.68228646
# ...

# %%
from sklearn.metrics import roc_curve, roc_auc_score
rf_auc = roc_auc_score(y_test, rf_probs)
lr_auc = roc_auc_score(y_test, lr_probs)
print(rf_auc)
print(lr_auc)
# Out:
# 0.9892722363198646
# 0.9454421237556119

# %%
rf_fpr, rf_tpr, _ = roc_curve(y_test, rf_probs)
lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs)

# %%
import matplotlib.pyplot as plt
plt.plot(rf_fpr, rf_tpr, marker='.', label="RandomForest(AUC=%0.3f)" %rf_auc)
plt.plot(lr_fpr, lr_tpr, marker='.', label="LogisticRegression(AUC=%0.3f)" %lr_auc)
plt.title("ROC Plot")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()
